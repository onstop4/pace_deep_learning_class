# %% [markdown]
# # LSTM
#
# ## Problem 1 - Univariate Forecasting

# %%
# !pip install --upgrade scalecast
# Out:
# Collecting scalecast
#   Downloading SCALECAST-0.19.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn>=1.3.1 (from scalecast)
#   Downloading scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 42.2 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from scalecast) (0.14.2)
# Collecting tbats (from scalecast)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from scalecast) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from scalecast) (3.7.1)
# Requirement already satisfied: seaborn>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from scalecast) (0.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from scalecast) (2.0.3)
# Requirement already satisfied: lightgbm>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from scalecast) (4.1.0)
# Requirement already satisfied: dask>=2023.3.2 in /usr/local/lib/python3.10/dist-packages (from scalecast) (2023.8.1)
# Collecting catboost (from scalecast)
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from scalecast) (3.1.2)
# Collecting shap (from scalecast)
#   Downloading shap-0.45.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (538 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 57.1 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=3.0 in /usr/local/lib/python3.10/dist-packages (from scalecast) (3.4.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (24.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (7.1.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.1->scalecast) (1.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scalecast) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scalecast) (2024.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost->scalecast) (0.20.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost->scalecast) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost->scalecast) (1.16.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->scalecast) (1.1.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap->scalecast) (4.66.2)
# Collecting slicer==0.0.7 (from shap->scalecast)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap->scalecast) (0.58.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->scalecast) (0.5.6)
# Collecting pmdarima (from tbats->scalecast)
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 93.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2023.3.2->scalecast) (3.18.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask>=2023.3.2->scalecast) (1.0.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap->scalecast) (0.41.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost->scalecast) (8.2.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima->tbats->scalecast) (3.0.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima->tbats->scalecast) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima->tbats->scalecast) (67.7.2)
# Building wheels for collected packages: scalecast
#   Building wheel for scalecast (setup.py) ... done
#   Created wheel for scalecast: filename=SCALECAST-0.19.8-py3-none-any.whl size=125274 sha256=18851f5af11341fd67e4b50c0c666cc3d110a2d31e8626934817e3cd634f4b75
#   Stored in directory: /root/.cache/pip/wheels/ac/67/2e/0244bcec7f41d76aae4c4196b64d31a20d474a7d5468f3d67e
# Successfully built scalecast
# Installing collected packages: slicer, scikit-learn, shap, catboost, pmdarima, tbats, scalecast
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed catboost-1.2.5 pmdarima-2.0.4 scalecast-0.19.8 scikit-learn-1.4.2 shap-0.45.0 slicer-0.0.7 tbats-1.1.3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scalecast.Forecaster import Forecaster
from scalecast.Pipeline import Transformer, Reverter, Pipeline
from scalecast.util import (
    find_optimal_transformation,
    gen_rnn_grid,
    backtest_for_resid_matrix,
    get_backtest_resid_matrix,
    overwrite_forecast_intervals,
    infer_apply_Xvar_selection,
)
from scalecast import GridGenerator
from tensorflow.keras.callbacks import EarlyStopping
import pandas_datareader as pdr

# %%
data = pd.read_csv('AirPassengers.csv',parse_dates=['Month'])

f = Forecaster(
    y=data['#Passengers'],
    current_dates=data['Month'],
    future_dates = 24,
)

f.plot()
plt.show()

# %%
def forecaster(f):
    f.set_estimator('rnn')
    f.manual_forecast(
        lags = 18,
        layers_struct = [
            ('LSTM',{'units':36,'activation':'tanh'}),
        ],
        epochs=200,
        call_me = 'lstm',
    )

transformer = Transformer(
    transformers = [
        ('DetrendTransform',{'poly_order':2}),
        'DeseasonTransform',
    ],
)

reverter = Reverter(
    reverters = [
        'DeseasonRevert',
        'DetrendRevert',
    ],
    base_transformer = transformer,
)

pipeline = Pipeline(
    steps = [
        ('Transform',transformer),
        ('Forecast',forecaster),
        ('Revert',reverter),
    ]
)

f = pipeline.fit_predict(f)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 3s 15ms/step - loss: 0.3722
# Epoch 2/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3517
# Epoch 3/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3301
# Epoch 4/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3051
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2746
# Epoch 6/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1191
# Epoch 139/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1192
# Epoch 140/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1199
# Epoch 141/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1194
# Epoch 142/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1192
# Epoch 143/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1193
# Epoch 144/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1190
# Epoch 145/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1188
# Epoch 146/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1185
# Epoch 147/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1181
# Epoch 148/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1183
# Epoch 149/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1181
# Epoch 150/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1178
# Epoch 151/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1177
# Epoch 152/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1176
# Epoch 153/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1184
# Epoch 154/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1177
# Epoch 155/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1174
# Epoch 156/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1169
# Epoch 157/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1170
# Epoch 158/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1174
# Epoch 159/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1169
# Epoch 160/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1171
# Epoch 161/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1163
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1165
# Epoch 163/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1161
# Epoch 164/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1159
# Epoch 165/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1160
# Epoch 166/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1160
# Epoch 167/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1157
# Epoch 168/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1153
# Epoch 169/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1157
# Epoch 170/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1154
# Epoch 171/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1152
# Epoch 172/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1150
# Epoch 173/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1151
# Epoch 174/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1147
# Epoch 175/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1142
# Epoch 176/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1144
# Epoch 177/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1140
# Epoch 178/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1137
# Epoch 179/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1134
# Epoch 180/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1132
# Epoch 181/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1133
# Epoch 182/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1133
# Epoch 183/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1126
# Epoch 184/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1124
# Epoch 185/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1124
# Epoch 186/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1120
# Epoch 187/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1119
# Epoch 188/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1115
# Epoch 189/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1113
# Epoch 190/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1112
# Epoch 191/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1107
# Epoch 192/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1106
# Epoch 193/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1102
# Epoch 194/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1098
# Epoch 195/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1100
# Epoch 196/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1099
# Epoch 197/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1091
# Epoch 198/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1086
# Epoch 199/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1078
# Epoch 200/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1083
# 1/1 [==============================] - 0s 415ms/step
# 4/4 [==============================] - 0s 3ms/step
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_PyDriveImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_OpenCVImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_BokehImportHook.find_spec() not found; falling back to find_module()
# WARNING:root:_AltairImportHook.find_spec() not found; falling back to find_module()

# %%
f.plot()
plt.savefig('LSTM Univariate.png')
plt.show()

# %% [markdown]
# ## Problem 2 - Multivariate Forecasting

# %%
data = pd.read_csv('avocado.csv')

# %%
# demand
vol = data.groupby('Date')['Total Volume'].sum()
# price
price = data.groupby('Date')['AveragePrice'].sum()

fvol = Forecaster(
    y = vol,
    current_dates = vol.index,
    test_length = 13,
    validation_length = 13,
    future_dates = 13,
    metrics = ['rmse','r2'],
)
fprice = Forecaster(
    y = price,
    current_dates = price.index,
    future_dates = 13,
)

# %%
fvol.plot()
plt.show()

# %%
transformer, reverter = find_optimal_transformation(
    fvol,
    set_aside_test_set=True, # prevents leakage so we can benchmark the resulting models fairly
    return_train_only = True, # prevents leakage so we can benchmark the resulting models fairly
    verbose=True,
    detrend_kwargs=[
        {'loess':True},
        {'poly_order':1},
        {'ln_trend':True},
    ],
    m = 52, # what makes one seasonal cycle?
    test_length = 4,
)
# Out:
# Using mlr model to find the best transformation set on 1 test sets, each 4 in length.
# All transformation tries will be evaluated with 52 lags.
# Last transformer tried:
# []
# Score (rmse): 10788435.478499787
# --------------------------------------------------
# Last transformer tried:
# [('DetrendTransform', {'loess': True})]
# Score (rmse): 17367936.069693502
# --------------------------------------------------
# Last transformer tried:
# [('DetrendTransform', {'poly_order': 1})]
# Score (rmse): 12269036.469923073
# --------------------------------------------------
# Last transformer tried:
# [('DetrendTransform', {'ln_trend': True})]
# Score (rmse): 12093617.597284073
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'})]
# Score (rmse): 9289548.042079167
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('Transform', BoxcoxTransform, {'lmbda': -0.5})]
# Score (rmse): 10446492.574351573
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('Transform', BoxcoxTransform, {'lmbda': 0})]
# Score (rmse): 10242650.677245773
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('Transform', BoxcoxTransform, {'lmbda': 0.5})]
# Score (rmse): 9836892.33327683
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('DiffTransform', 1)]
# Score (rmse): 9702659.46289694
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('DiffTransform', 52)]
# Score (rmse): 36977467.90336875
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('ScaleTransform',)]
# Score (rmse): 9289548.042079171
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('MinMaxTransform',)]
# Score (rmse): 9289548.042079167
# --------------------------------------------------
# Last transformer tried:
# [('DeseasonTransform', {'m': 52, 'model': 'add'}), ('RobustScaleTransform',)]
# Score (rmse): 9289548.042079171
# --------------------------------------------------
# Final Selection:
# [('DeseasonTransform', {'m': 52, 'model': 'add', 'train_only': True})]

# %%
fprice = transformer.fit_transform(fprice)
fvol = transformer.fit_transform(fvol)

# %%
rnn_grid = gen_rnn_grid(
    layer_tries = 10,
    min_layer_size = 3,
    max_layer_size = 5,
    units_pool = [100],
    epochs = [100],
    dropout_pool = [0,0.05],
    validation_split=.2,
    callbacks=EarlyStopping(
      monitor='val_loss',
      patience=3,
    ),
    random_seed = 20,
) # creates a grid of hyperparameter values to tune the LSTM model

# %%
def forecaster(fvol,fprice):
    # naive forecast for benchmarking
    fvol.set_estimator('naive')
    fvol.manual_forecast()
    # univariate lstm model
    fvol.add_ar_terms(13) # the model will use 13 series lags
    fvol.set_estimator('rnn')
    fvol.ingest_grid(rnn_grid)
    fvol.tune()
    fvol.auto_forecast(call_me='lstm_univariate')
    # multivariate lstm model
    fvol.add_series(fprice.y,called='price')
    fvol.add_lagged_terms('price',lags=13,drop=True)
    fvol.ingest_grid(rnn_grid)
    fvol.tune()
    fvol.auto_forecast(call_me='lstm_multivariate')

# %%
forecaster(fvol=fvol,fprice=fprice)
# Out:
# 1/1 [==============================] - 0s 358ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 153ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 338ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7cfb20108ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 147ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:6 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7cfaf9a14a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 335ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 336ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 319ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 149ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 341ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 324ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 171ms/step
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 169ms/step
# 5/5 [==============================] - 0s 5ms/step
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 349ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 168ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 316ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 143ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 499ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 365ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 369ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 149ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 366ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 352ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 334ms/step
# 5/5 [==============================] - 0s 3ms/step

# %%
fvol = reverter.fit_transform(fvol)

# %%
fvol.plot_test_set(order_by='TestSetRMSE')
plt.savefig('LSTM MV test results.png')
plt.show()

# %%
pd.options.display.float_format = '{:,.4f}'.format
summ = fvol.export('model_summaries',determine_best_by='TestSetRMSE')
summ[['ModelNickname','TestSetRMSE','TestSetR2']]
# Out:
#        ModelNickname     TestSetRMSE  TestSetR2
# 0  lstm_multivariate 13,240,612.9150     0.3838
# 1    lstm_univariate 14,604,780.9968     0.2503
# 2              naive 17,403,456.6059    -0.0646

# %%
summ[['ModelNickname','HyperParams']].style.set_properties(height = 5)
# Out:
# <style type="text/css">
# #T_ef99b_row0_col0, #T_ef99b_row0_col1, #T_ef99b_row1_col0, #T_ef99b_row1_col1, #T_ef99b_row2_col0, #T_ef99b_row2_col1 {
#   height: 5;
# }
# </style>
# <table id="T_ef99b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef99b_level0_col0" class="col_heading level0 col0" >ModelNickname</th>
#       <th id="T_ef99b_level0_col1" class="col_heading level0 col1" >HyperParams</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef99b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef99b_row0_col0" class="data row0 col0" >lstm_multivariate</td>
#       <td id="T_ef99b_row0_col1" class="data row0 col1" >{'verbose': 0, 'epochs': 100, 'validation_split': 0.2, 'callbacks': <keras.src.callbacks.EarlyStopping object at 0x7cfb001392d0>, 'layers_struct': [('LSTM', {'units': 100, 'activation': 'tanh', 'dropout': 0.0, 'return_sequences': False}, 'LSTM', {'units': 100, 'activation': 'tanh', 'dropout': 0.0}, 'LSTM', {'units': 100, 'activation': 'tanh', 'dropout': 0.0}, 'LSTM', {'units': 100, 'activation': 'tanh', 'dropout': 0.0}, 'LSTM', {'units': 100, 'activation': 'tanh', 'dropout': 0.0})]}</td>
#     </tr>
#     <tr>
#       <th id="T_ef99b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef99b_row1_col0" class="data row1 col0" >lstm_univariate</td>
#       <td id="T_ef99b_row1_col1" class="data row1 col1" >{'verbose': 0, 'epochs': 100, 'validation_split': 0.2, 'callbacks': <keras.src.callbacks.EarlyStopping object at 0x7cfb001392d0>, 'layers_struct': [('LSTM', {'units': 100, 'activation': 'relu', 'dropout': 0.05, 'return_sequences': False}, 'LSTM', {'units': 100, 'activation': 'relu', 'dropout': 0.05}, 'LSTM', {'units': 100, 'activation': 'relu', 'dropout': 0.05})]}</td>
#     </tr>
#     <tr>
#       <th id="T_ef99b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef99b_row2_col0" class="data row2 col0" >naive</td>
#       <td id="T_ef99b_row2_col1" class="data row2 col1" >{}</td>
#     </tr>
#   </tbody>
# </table>

# %%
fvol.plot(order_by='TestSetRMSE')
plt.show()

# %% [markdown]
# ## Problem 3 - Probabilistic Forecasting

# %%
df = pdr.get_data_fred(
    'HOUSTNSA',
    start = '1959-01-01',
    end = '2022-12-31',
)

f = Forecaster(
    y = df['HOUSTNSA'],
    current_dates = df.index,
    future_dates = 24, # 2-year forecast horizon
    test_length = .1, # 10% test length
    cis = True,
    cilevel = .9, # 90% intervals
)

f.plot()
plt.show()

# %%
transformer, reverter = find_optimal_transformation(
    f,
    estimator = 'lstm',
    epochs = 10,
    set_aside_test_set=True, # prevents leakage so we can benchmark the resulting models fairly
    return_train_only = True, # prevents leakage so we can benchmark the resulting models fairly
    verbose=True,
    m = 52, # what makes one seasonal cycle?
    test_length = 24,
    num_test_sets = 3,
    space_between_sets = 12,
    detrend_kwargs=[
        {'loess':True},
        {'poly_order':1},
        {'ln_trend':True},
    ],
)
# Out:
# Using lstm model to find the best transformation set on 3 test sets, each 24 in length.
# Epoch 1/10
# 17/17 [==============================] - 2s 4ms/step - loss: 0.4275
# Epoch 2/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4068
# Epoch 3/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3839
# Epoch 4/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3576
# Epoch 5/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3269
# Epoch 6/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2923
# Epoch 7/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2564
# Epoch 8/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2229
# Epoch 9/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1951
# Epoch 10/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1753
# 1/1 [==============================] - 0s 338ms/step
# Epoch 1/10
# 21/21 [==============================] - 2s 4ms/step - loss: 0.4298
# Epoch 2/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.
10
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1887
# 1/1 [==============================] - 0s 328ms/step
# 19/19 [==============================] - 0s 2ms/step
# Epoch 1/10
# 15/15 [==============================] - 2s 4ms/step - loss: 0.4937
# Epoch 2/10
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4737
# Epoch 3/10
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4514
# Epoch 4/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4264
# Epoch 5/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3981
# Epoch 6/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3667
# Epoch 7/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3326
# Epoch 8/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2975
# Epoch 9/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2637
# Epoch 10/10
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2328
# 1/1 [==============================] - 0s 347ms/step
# Epoch 1/10
# 19/19 [==============================] - 2s 6ms/step - loss: 0.4725
# Epoch 2/10
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4433
# Epoch 3/10
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4109
# Epoch 4/10
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3743
# Epoch 5/10
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3342
# Epoch 6/10
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2911
# Epoch 7/10
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2495
# Epoch 8/10
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2132
# Epoch 9/10
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1866
# Epoch 10/10
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1694
# 1/1 [==============================] - 0s 353ms/step
# 19/19 [==============================] - 0s 2ms/step
# Epoch 1/10
# 14/14 [==============================] - 2s 4ms/step - loss: 0.4965
# Epoch 2/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4785
# Epoch 3/10
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4598
# Epoch 4/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4396
# Epoch 5/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4170
# Epoch 6/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3913
# Epoch 7/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3625
# Epoch 8/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3312
# Epoch 9/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2988
# Epoch 10/10
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2669
# 1/1 [==============================] - 0s 353ms/step
# Epoch 1/10
# 18/18 [==============================] - 2s 4ms/step - loss: 0.4931
# Epoch 2/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4715
# Epoch 3/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4486
# Epoch 4/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4226
# Epoch 5/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3921
# Epoch 6/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3567
# Epoch 7/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3170
# Epoch 8/10
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2753
# Epoch 9/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2349
# Epoch 10/10
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2017
# 1/1 [==============================] - 0s 352ms/step
# 18/18 [==============================] - 0s 2ms/step
# Last transformer tried:
# [('DetrendTransform', {'poly_order': 1}), ('DeseasonTransform', {'m': 52, 'model': 'add'}), ('DiffTransform', 52)]
# Score (rmse): 64.77290867845083
# --------------------------------------------------
# Epoch 1/10
# 17/17 [==============================] - 2s 6ms/step - loss: 0.4667
# Epoch 2/10
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4443
# Epoch 3/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4206
# Epoch 4/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3943
# Epoch 5/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3645
# Epoch 6/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3313
# Epoch 7/10
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2955
# Epoch 8/10
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2593
# Epoch 9/10
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2269
# Epoch 10/10
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2010
# 1/1 [==============================] - 0s 323ms/step
# Epoch 1/10
# 21/21 [==============================] - 3s 5ms/step - loss: 0.4361
# Epoch 2/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4096
# Epoch 3/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3809
# Epoch 4/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3482
# Epoch 5/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3114
# Epoch 6/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2723
# Epoch 7/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2338
# Epoch 8/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2018
# Epoch 9/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1796
# Epoch 10/10
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1668
# 1/1 [==============================] - 0s 354ms/step
# 21/21 [==============================] - 0s 2ms/step
# Epoch 1/10
# 16/16 [==============================] - 2s 5ms/step - loss: 0.4740
# Epoch 2/10
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4534
# Epoch 3/10
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4302
# Epoch 4/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4038
# Epoch 5/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3738
# Epoch 6/10
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3401
# Epoch 7/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3038
# Epoch 8/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2672
# Epoch 9/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2335
# Epoch 10/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2059
# 1/1 [==============================] - 0s 353ms/step
# Epoch 1/10
# 20/20 [==============================] - 3s 6ms/step - loss: 0.4523
# Epoch 2/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4261
# Epoch 3/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3988
# Epoch 4/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3690
# Epoch 5/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3358
# Epoch 6/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2997
# Epoch 7/10
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2618
# Epoch 8/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2264
# Epoch 9/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1975
# Epoch 10/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1772
# 1/1 [==============================] - 0s 358ms/step
# 20/20 [==============================] - 0s 2ms/step
# Epoch 1/10
# 16/16 [==============================] - 2s 5ms/step - loss: 0.4801
# Epoch 2/10
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4588
# Epoch 3/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4352
# Epoch 4/10
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4083
# Epoch 5/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3774
# Epoch 6/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3426
# Epoch 7/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3050
# Epoch 8/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2669
# Epoch 9/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2319
# Epoch 10/10
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2034
# 1/1 [==============================] - 0s 349ms/step
# Epoch 1/10
# 20/20 [==============================] - 2s 4ms/step - loss: 0.4648
# Epoch 2/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4388
# Epoch 3/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4111
# Epoch 4/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3798
# Epoch 5/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3435
# Epoch 6/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3029
# Epoch 7/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2601
# Epoch 8/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2216
# Epoch 9/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1919
# Epoch 10/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1720
# 1/1 [==============================] - 0s 353ms/step
# 20/20 [==============================] - 0s 2ms/step
# Last transformer tried:
# [('DetrendTransform', {'poly_order': 1}), ('DeseasonTransform', {'m': 52, 'model': 'add'}), ('ScaleTransform',)]
# Score (rmse): 15.048356882933659
# --------------------------------------------------
# Epoch 1/10
# 17/17 [==============================] - 2s 4ms/step - loss: 0.4668
# Epoch 2/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4470
# Epoch 3/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4262
# Epoch 4/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4027
# Epoch 5/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3754
# Epoch 6/10
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3430
# Epoch 7/10
# ...
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# Last transformer tried:
# [('DetrendTransform', {'poly_order': 1}), ('DeseasonTransform', {'m': 52, 'model': 'add'}), ('RobustScaleTransform',)]
# Score (rmse): 14.273771263226564
# --------------------------------------------------
# Final Selection:
# [('DetrendTransform', {'poly_order': 1, 'train_only': True}), ('DeseasonTransform', {'m': 52, 'model': 'add', 'train_only': True})]
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:invalid value encountered in log
# WARNING:root:Lambda value of 0 cannot be evaluated. error: Input contains NaN.
# WARNING:root:Lambda value of 0.5 cannot be evaluated. error: Complex data not supported
# [-2.        +5.19890005j  0.8655432 +0.j         -2.        +8.47922658j
#  -2.       +10.40979792j -2.       +10.91588464j -2.       +12.43894243j
#  -2.       +15.64088373j -2.       +16.79141689j -2.       +17.08822808j
#  -2.       +16.86300774j -2.       +15.85337849j -2.       +15.58134675j
#  -2.       +14.05879116j -2.       +13.19624832j -2.       +14.227071j
#  -2.       +14.29622241j -2.       +14.28719453j -2.       +15.50712447j
#  -2.       +15.97723485j -2.       +17.27980893j -2.       +16.71620118j
#  -2.       +16.50386247j -2.       +14.93255715j -2.       +14.02386458j
#  -2.       +13.45931232j -2.       +14.39441038j -2.       +14.31787074j
#  -2.       +13.12431733j -2.       +13.85608542j -2.       +15.25551229j
#  -2.       +16.19082961j -2.       +17.22626989j -2.       +16.58793564j
#  -2.       +17.22972613j -2.       +15.93960986j -2.       +15.97811517j
#  -2.       +14.97527134j -2.       +14.57062587j -2.       +15.06265644j
#  -2.       +15.37886102j -2.       +14.07859053j -2.       +15.12392311j
#  -2.       +15.13635984j -2.       +16.12359586j -2.       +15.35378437j
#  -2.       +15.27180576j -2.       +14.59281495j -2.       +13.23576454j
#  -2.       +12.94670334j -2.       +11.82011269j -2.       +12.56371804j
#  -2.       +12.35358076j -2.        +8.97135772j -2.        +9.14578371j
#  -2.       +12.63938214j -2.       +12.2890435j  -2.       +13.03124073j
#  -2.       +12.36866955j -2.        +9.5547863j  -2.       +10.8355147j
#  -2.        +7.78872497j -2.       +10.51749625j -2.        +8.71701251j
#  -2.        +9.0019478j  -2.        +9.09430077j -2.        +9.31652656j
#  -2.        +9.17966486j -2.       +11.63781219j -2.       +12.71143678j
#  -2.       +12.16254936j -2.        +9.67102533j -2.        +7.43293307j
#  -2.        +7.40864897j -2.        +8.70828192j -2.        +5.25718182j
#  -2.        +9.4723532j ]

# %%
rnn_grid = gen_rnn_grid(
    layer_tries = 100,
    min_layer_size = 1,
    max_layer_size = 5,
    units_pool = [100],
    epochs = [100],
    dropout_pool = [0,0.05],
    validation_split=.2,
    callbacks=EarlyStopping(
      monitor='val_loss',
      patience=3,
    ),
    random_seed = 20,
) # make a really big grid and limit it manually

# %%
def forecaster(f,grid):
    f.auto_Xvar_select(
        try_trend=False,
        try_seasonalities=False,
        max_ar=100
    )
    f.set_estimator('rnn')
    f.ingest_grid(grid)
    f.limit_grid_size(10) # randomly reduce the big grid to 10
    f.cross_validate(k=3,test_length=24) # three-fold cross-validation
    f.auto_forecast()

# %%
pipeline = Pipeline(
    steps = [
        ('Transform',transformer),
        ('Forecast',forecaster),
        ('Revert',reverter),
    ]
)

f = pipeline.fit_predict(f,grid=rnn_grid)
# Out:
# 1/1 [==============================] - 0s 338ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 476ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_90 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 145ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 359ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 487ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 351ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_94 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 164ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 338ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 345ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_97 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 151ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 356ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 324ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_100 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 152ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 325ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 344ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 344ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_104 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 157ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 327ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 339ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_107 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 143ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 354ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 1s 524ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_110 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 140ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 347ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 475ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 346ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_114 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 152ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 338ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# 1/1 [==============================] - 0s 347ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_117 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 151ms/step
# WARNING:root:The dynamic_testing arg is always set to True for the rnn model. This model uses direct forecasting with lags.
# WARNING:tensorflow:Layer lstm_117 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 367ms/step
# 23/23 [==============================] - 0s 3ms/step

# %%
f.plot(ci=True)
plt.savefig('Probabilistic LSTM.png')
plt.show()

# %% [markdown]
# ## Problem 4 - Dynamic Probabilistic Forecasting

# %%
params = f.best_params
num_chosen_lags = len(f.get_regressor_names())

# %%
def forecaster(f,params):
    f.set_estimator('rnn')
    f.manual_forecast(**params,test_again=False,lags=num_chosen_lags)

# %%
pipeline = Pipeline(
    steps = [
        ('Transform',transformer),
        ('Forecast',forecaster),
        ('Revert',reverter),
    ]
)

# %%
f = pipeline.fit_predict(f,params = params)
# Out:
# 1/1 [==============================] - 0s 347ms/step
# 23/23 [==============================] - 0s 2ms/step

# %%
backtest_results = backtest_for_resid_matrix(
    f,
    pipeline=pipeline,
    alpha = .1,
    jump_back = 12,
    params = f.best_params,
)
# Out:
# 1/1 [==============================] - 1s 513ms/step
# 23/23 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 350ms/step
# 22/22 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 342ms/step
# 22/22 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 332ms/step
# 22/22 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 334ms/step
# 21/21 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 347ms/step
# 21/21 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 358ms/step
# 20/20 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 409ms/step
# 20/20 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 344ms/step
# 20/20 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 352ms/step
# 19/19 [==============================] - 0s 2ms/step

# %%
backtest_resid_matrix = get_backtest_resid_matrix(backtest_results)

# %%
pd.options.display.max_columns = None
fig, ax = plt.subplots(figsize=(16,8))
mat = pd.DataFrame(np.abs(backtest_resid_matrix[0]['rnn']))
sns.heatmap(
    mat.round(1),
    annot = True,
    ax = ax,
    cmap = sns.color_palette("icefire", as_cmap=True),
)
plt.ylabel('Backtest Iteration',size=16)
plt.xlabel('Forecast Step',size = 16)
plt.title('Absolute Residuals from LSTM Backtest',size=25)
plt.savefig('LSTM Resid Matrix.png')
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,8))
sns.heatmap(
    pd.DataFrame({'Mean Residuals':mat.mean().round(1)}),
    annot = True,
    cmap = 'cubehelix_r',
    ax = ax[0],
    annot_kws={"fontsize": 16},
)
cbar = ax[0].collections[0].colorbar
cbar.ax.invert_yaxis()
ax[0].set_title('Mean Absolute Residuals',size=20)
ax[0].set_ylabel('Forecast Step',size=15)
ax[0].set_xlabel('')
sns.heatmap(
    pd.DataFrame({'Residuals 95 Percentile':np.percentile(mat, q=95, axis = 0)}),
    annot = True,
    cmap = 'cubehelix_r',
    ax = ax[1],
    annot_kws={"fontsize": 16},
)
cbar = ax[1].collections[0].colorbar
cbar.ax.invert_yaxis()
ax[1].set_title('Absolute Residual 95 Percentiles',size=20)
ax[1].set_ylabel('Forecast Step',size=15)
ax[1].set_xlabel('')
plt.show()

# %%
overwrite_forecast_intervals(f,backtest_resid_matrix=backtest_resid_matrix,alpha=.1)

# %%
f.plot(ci=True)
plt.savefig('LSTM dynamic intervals.png')
plt.show()

# %% [markdown]
# ## Problem 5 - Transfer Learning
#
# ### Scenario 1: New data from the same series

# %%
df = pdr.get_data_fred(
    'HOUSTNSA',
    start = '1959-01-01',
    end = '2026-06-30',
)

f_new = Forecaster(
    y = df.iloc[:,0],
    current_dates = df.index,
    future_dates = 24, # 2-year forecast horizon
)

f_new.plot()
plt.show()

# %%
def transfer_forecast(f_new,transfer_from):
    f_new = infer_apply_Xvar_selection(
        infer_from=transfer_from,
        apply_to=f_new
    )
    f_new.transfer_predict(
        transfer_from=transfer_from,
        model='rnn',
        model_type='tf'
    )

# %%
pipeline_can = Pipeline(
    steps = [
        ('Transform',transformer),
        ('Transfer Forecast',transfer_forecast),
        ('Revert',reverter),
    ]
)

f_new = pipeline_can.fit_predict(f_new,transfer_from=f)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 24/24 [==============================] - 0s 2ms/step

# %%
f_new.plot()
plt.title('Housing Starts Forecast with Actuals Through June, 2026')
plt.savefig('RNN transferred same series.png')
plt.show()

# %% [markdown]
# ### Scenario 2: A new time series with similar characteristics

# %%
df = pdr.get_data_fred(
    'CANWSCNDW01STSAM',
    start = '2010-01-01',
    end = '2025-12-31',
)

f_new = Forecaster(
    y = df.iloc[:,0],
    current_dates = df.index,
    future_dates = 24, # 2-year forecast horizon
)

f_new.plot()
plt.show()

# %%
def transfer_forecast(f_new,transfer_from):
    f_new = infer_apply_Xvar_selection(
        infer_from=transfer_from,
        apply_to=f_new
    )
    f_new.transfer_predict(
        transfer_from=transfer_from,
        model='rnn',
        model_type='tf'
    )

# %%
pipeline_can = Pipeline(
    steps = [
        ('Transform',transformer),
        ('Transfer Forecast',transfer_forecast),
        ('Revert',reverter),
    ]
)

f_new = pipeline_can.fit_predict(f_new,transfer_from=f)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 5/5 [==============================] - 0s 4ms/step

# %%
f_new.plot()
plt.title('Candian Housing Starts Forecast')
plt.savefig('Transferred RNN Canada')
plt.show()
